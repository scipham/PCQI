# %%
# %pip install --quiet netket
# %pip install https://github.com/PhilipVinc/netket_dynamics.git
# Out:
# ...
#      | 171 kB 2.0 MB/s
#   ERROR: Cannot unpack file /tmp/pip-unpack-skytjcbp/netket_dynamics.git (downloaded from /tmp/pip-req-build-6vjfnx0f, content-type: text/html; charset=utf-8); cannot detect archive format
# ERROR: Cannot determine archive format of /tmp/pip-req-build-6vjfnx0f

# %%
import netket as nk
import netket_dynamics as nkd

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-4878ccd79b38> in <module>()
#       1
#       2 import netket as nk
# ----> 3 import netket_dynamics as nkd
#       4
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'netket_dynamics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from test import test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-0c297a7e9baa> in <module>()
# ----> 1 from test.py import test
#
# ModuleNotFoundError: No module named 'test.py'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
